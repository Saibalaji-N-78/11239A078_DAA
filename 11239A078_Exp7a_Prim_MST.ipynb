# %%
def prim(graph):
    n = len(graph)
    selected = [False] * n
    selected[0] = True
    edges, cost = [], 0

    for _ in range(n - 1):
        min_edge = (None, None, float('inf'))
        for u in range(n):
            if selected[u]:
                for v in range(n):
                    if not selected[v] and 0 < graph[u][v] < min_edge[2]:
                        min_edge = (u, v, graph[u][v])
        u, v, w = min_edge
        selected[v] = True
        edges.append((u, v, w))
        cost += w

    print("Edges in MST:")
    for u, v, w in edges:
        print(f"{u} - {v} : {w}")
    print(f"\nTotal Cost: {cost}")

# Example usage
graph = [
    [0, 2, 0, 6, 0],
    [2, 0, 3, 8, 5],
    [0, 3, 0, 0, 7],
    [6, 8, 0, 0, 9],
    [0, 5, 7, 9, 0]
]
prim(graph)
# Out:
# Edges in MST:
# 0 - 1 : 2
# 1 - 2 : 3
# 1 - 4 : 5
# 0 - 3 : 6
#
# Total Cost: 16
